# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
model=Sequential()
model.add(Conv2D(filters=64, kernel_size=(5, 5), input_shape=(32, 32, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        102464
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         204928
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         409728
#
#  max_pooling2d_1 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 10)                5130
#
# =================================================================
# Total params: 727114 (2.77 MB)
# Trainable params: 727114 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cifar10=keras.datasets.cifar10
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label_original=train_label
train_label = keras.utils.to_categorical(train_label)
test_label = keras.utils.to_categorical(test_label)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
import matplotlib.pyplot as plt
category=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.imshow(train_data[0])
plt.title(category[int(train_label_original[0])])
plt.show()
print(train_label_original[0])
# Out:
# [6]

# %%
train_history=model.fit(train_data,train_label,epochs=30,batch_size=512)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 20s 58ms/step - loss: 8.2786 - accuracy: 0.1680
# Epoch 2/30
# 98/98 [==============================] - 4s 39ms/step - loss: 2.3179 - accuracy: 0.2224
# Epoch 3/30
# 98/98 [==============================] - 4s 39ms/step - loss: 2.0906 - accuracy: 0.2667
# Epoch 4/30
# 98/98 [==============================] - 4s 40ms/step - loss: 2.0347 - accuracy: 0.2971
# Epoch 5/30
# 98/98 [==============================] - 4s 39ms/step - loss: 1.8454 - accuracy: 0.3597
# Epoch 6/30
# 98/98 [==============================] - 4s 39ms/step - loss: 1.6615 - accuracy: 0.4247
# Epoch 7/30
# 98/98 [==============================] - 4s 40ms/step - loss: 1.5370 - accuracy: 0.4662
# Epoch 8/30
# 98/98 [==============================] - 4s 39ms/step - loss: 1.4057 - accuracy: 0.5114
# Epoch 9/30
# 98/98 [==============================] - 4s 40ms/step - loss: 1.3040 - accuracy: 0.5483
# Epoch 10/30
# 98/98 [==============================] - 4s 40ms/step - loss: 1.1826 - accuracy: 0.5943
# Epoch 11/30
# 98/98 [==============================] - 4s 40ms/step - loss: 1.0762 - accuracy: 0.6297
# Epoch 12/30
# 98/98 [==============================] - 4s 40ms/step - loss: 0.9860 - accuracy: 0.6612
# Epoch 13/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.8762 - accuracy: 0.7021
# Epoch 14/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.7704 - accuracy: 0.7355
# Epoch 15/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.6782 - accuracy: 0.7671
# Epoch 16/30
# 98/98 [==============================] - 4s 43ms/step - loss: 0.5792 - accuracy: 0.8009
# Epoch 17/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.5070 - accuracy: 0.8263
# Epoch 18/30
# 98/98 [==============================] - 4s 40ms/step - loss: 0.4343 - accuracy: 0.8539
# Epoch 19/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.3936 - accuracy: 0.8676
# Epoch 20/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.3298 - accuracy: 0.8910
# Epoch 21/30
# 98/98 [==============================] - 4s 40ms/step - loss: 0.3115 - accuracy: 0.8970
# Epoch 22/30
# 98/98 [==============================] - 4s 43ms/step - loss: 0.3052 - accuracy: 0.9045
# Epoch 23/30
# 98/98 [==============================] - 4s 43ms/step - loss: 0.2654 - accuracy: 0.9158
# Epoch 24/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.2669 - accuracy: 0.9168
# Epoch 25/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.2297 - accuracy: 0.9292
# Epoch 26/30
# 98/98 [==============================] - 4s 42ms/step - loss: 0.2255 - accuracy: 0.9317
# Epoch 27/30
# 98/98 [==============================] - 4s 40ms/step - loss: 0.2408 - accuracy: 0.9306
# Epoch 28/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.2204 - accuracy: 0.9344
# Epoch 29/30
# 98/98 [==============================] - 4s 41ms/step - loss: 0.2145 - accuracy: 0.9371
# Epoch 30/30
# 98/98 [==============================] - 4s 40ms/step - loss: 0.1922 - accuracy: 0.9425

# %%
score=model.evaluate(test_data, test_label)
print(score[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 3.5944 - accuracy: 0.5853
# 0.5853000283241272

# %%
#繪製正確性與損失歷史圖
import matplotlib.pyplot as plt
import numpy as np

def show_train_history(train_history, train):
    plt.plot(train_history.history[train])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train'], loc='center right')
    plt.show()

show_train_history(train_history, 'accuracy')
show_train_history(train_history, 'loss')
